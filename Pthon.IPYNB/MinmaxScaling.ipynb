# %%
import pandas as pd
crime=pd.read_csv('crime-q2-2022.csv')
print(crime.columns)
# Out:
# Index(['park', 'assassination', 'theft', 'gang_rape', 'burglary', 'rape',
#        'assualt_attack', 'harassment(sexual)', 'totalcrime', 'long', 'lat',
#        'area', 'crime/area'],
#       dtype='object')

# %%
#crime.rename(columns={'park' : 'nm_pol','harassment': 'harassment(sexual)','total crime': 'totalcrime' ,' long' : 'long' , 'assult_attack' :'assualt_attack'})

# %%
columnsTitles =['park', 'assassination', 'theft', 'gang_rape', 'burglary', 'rape',
       'assualt_attack', 'harassment(sexual)', 'totalcrime', 'long',
       'lat', 'area', 'crime/area']

crime = crime.reindex(columns=columnsTitles)

# %%
print(crime.columns)
# Out:
# Index(['park', 'assassination', 'theft', 'gang_rape', 'burglary', 'rape',
#        'assualt_attack', 'harassment(sexual)', 'totalcrime', 'long', 'lat',
#        'area', 'crime/area'],
#       dtype='object')

# %%
crime
# Out:
#                               park  assassination  theft  gang_rape  burglary  \
# 0                  PELHAM BAY PARK              0      0          0         0
# 1               VAN CORTLANDT PARK              0      0          0         0
# 2     ROCKAWAY BEACH AND BOARDWALK              0      0          0         0
# 3                  FRESHKILLS PARK              0      0          0         0
# 4     FLUSHING MEADOWS CORONA PARK              0      3          0         3
# ...                            ...            ...    ...        ...       ...
# 1149              MOHEGAN TRIANGLE              0      0          0         0
# 1150    PLAYGROUND OF THE AMERICAS              0      0          0         0
# 1151     PRIVATE WILLIAM GRAY PARK              0      0          0         0
# 1152         ADRIENNE'S PLAYGROUND              0      0          0         0
# 1153                         TOTAL              2      4          7         5
#
# ...

# %%
crime.dtypes
# Out:
# park                   object
# assassination           int64
# theft                   int64
# gang_rape               int64
# burglary                int64
# rape                    int64
# assualt_attack          int64
# harassment(sexual)      int64
# totalcrime              int64
# long                  float64
# lat                   float64
# area                   object
# crime/area            float64
# dtype: object

# %%
pip install GoogleMaps
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd
from geopy.geocoders import Nominatim

crime['lat'] = ""
crime['long'] = ""

geolocator = Nominatim(user_agent="myApp")

for i in crime.index:
    try:
        #tries fetch address from geopy
        location = geolocator.geocode(crime['park'][i])
        
        #append lat/long to column using dataframe location
        crime.loc[i,'lat'] = location.latitude
        crime.loc[i,'long'] = location.longitude
  
    except:
        #catches exception for the case where no value is returned
        #appends null value to column
        crime.loc[i,'location_lat'] = ""
        crime.loc[i,'location_long'] = ""

# %%
crime
# Out:
#                               park  assassination  theft  gang_rape  burglary  \
# 0                  PELHAM BAY PARK              0      0          0         0
# 1               VAN CORTLANDT PARK              0      0          0         0
# 2     ROCKAWAY BEACH AND BOARDWALK              0      0          0         0
# 3                  FRESHKILLS PARK              0      0          0         0
# 4     FLUSHING MEADOWS CORONA PARK              0      3          0         3
# ...                            ...            ...    ...        ...       ...
# 1149              MOHEGAN TRIANGLE              0      0          0         0
# 1150    PLAYGROUND OF THE AMERICAS              0      0          0         0
# 1151     PRIVATE WILLIAM GRAY PARK              0      0          0         0
# 1152         ADRIENNE'S PLAYGROUND              0      0          0         0
# 1153                         TOTAL              2      4          7         5
#
# ...

# %%
crime.loc[crime["assassination"], 'assassination'] += 2

# %%
crime.loc[crime["rape"], 'rape'] += 1

# %%
crime.loc[crime["gang_rape"], 'gang_rape'] += 1

# %%
crime.loc[crime["burglary"], 'burglary'] += 3

# %%
crime.loc[crime["assualt_attack"], 'assualt_attack'] += 2

# %%
crime.loc[crime["harassment(sexual)"], 'harassment(sexual)'] += 1

# %%
crime
# Out:
#                               park  assassination  theft  gang_rape  burglary  \
# 0                  PELHAM BAY PARK              2      0          1         3
# 1               VAN CORTLANDT PARK              2      0          1         3
# 2     ROCKAWAY BEACH AND BOARDWALK              2      0          1         3
# 3                  FRESHKILLS PARK              2      0          1         3
# 4     FLUSHING MEADOWS CORONA PARK              2      3          1         3
# ...                            ...            ...    ...        ...       ...
# 1149              MOHEGAN TRIANGLE              2      0          1         3
# 1150    PLAYGROUND OF THE AMERICAS              2      0          1         3
# 1151     PRIVATE WILLIAM GRAY PARK              2      0          1         3
# 1152         ADRIENNE'S PLAYGROUND              2      0          1         3
# 1153                         TOTAL              2      4          1         3
#
# ...

# %%
crime.to_csv('crimedata.csv')
