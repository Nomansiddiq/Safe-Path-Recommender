# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
crime_data = pd.read_csv("Crime_Map_.csv")

# %% [markdown]
# ```
# ```
#
# # Veiwing Data

# %%
crime_data.head(5)
# Out:
#   CMPLNT_NUM  ADDR_PCT_CD        BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM  \
# 0  247853895         43.0          BRONX   07/11/2022     09:09:00
# 1  250722124         67.0       BROOKLYN   01/01/2021     12:00:00
# 2  239511545        120.0  STATEN ISLAND   12/24/2021     08:00:00
# 3  247992275        115.0         QUEENS   06/15/2015     00:01:00
# 4  239602232         75.0       BROOKLYN   01/01/2018     09:00:00
#
#   CMPLNT_TO_DT CMPLNT_TO_TM CRM_ATPT_CPTD_CD HADEVELOPT        JURIS_DESC  \
# 0          NaN       (null)        COMPLETED     (null)  N.Y. POLICE DEPT
# 1   09/07/2022     12:00:00        COMPLETED     (null)  N.Y. POLICE DEPT
# 2   01/03/2022     08:00:00        COMPLETED     (null)  N.Y. POLICE DEPT
# 3   07/13/2022     17:00:00        COMPLETED     (null)  N.Y. POLICE DEPT
# 4   04/14/2021     23:59:00        COMPLETED     (null)  N.Y. POLICE DEPT
#
#    ...  PARKS_NM  PD_CD                                            PD_DESC  \
# ...

# %%
crime_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35152 entries, 0 to 35151
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CMPLNT_NUM         35152 non-null  object
#  1   ADDR_PCT_CD        35151 non-null  float64
#  2   BORO_NM            35152 non-null  object
#  3   CMPLNT_FR_DT       35152 non-null  object
#  4   CMPLNT_FR_TM       35152 non-null  object
#  5   CMPLNT_TO_DT       32004 non-null  object
#  6   CMPLNT_TO_TM       35151 non-null  object
#  7   CRM_ATPT_CPTD_CD   35151 non-null  object
#  8   HADEVELOPT         35151 non-null  object
#  9   JURIS_DESC         35151 non-null  object
#  10  KY_CD              35151 non-null  float64
#  11  LAW_CAT_CD         35151 non-null  object
#  12  LOC_OF_OCCUR_DESC  35151 non-null  object
#  13  OFNS_DESC          35151 non-null  object
#  14  PARKS_NM           35151 non-null  object
#  15  PD_CD              35106 non-null  float64
# ...

# %%
# Extracting the only needed 
selection = crime_data[["PD_DESC","Lat_Lon" , "BORO_NM"]]
selection
# Out:
#                                                  PD_DESC  \
# 0                                           ROBBERY,BANK
# 1                                                 RAPE 2
# 2      LARCENY,GRAND BY CREDIT CARD ACCT COMPROMISE-E...
# 3                              FRAUD,UNCLASSIFIED-FELONY
# 4                              FRAUD,UNCLASSIFIED-FELONY
# ...                                                  ...
# 35147                   CRIMINAL MISCHIEF,UNCLASSIFIED 4
# 35148                                          ASSAULT 3
# 35149                     CONTROLLED SUBSTANCE, POSSESSI
# 35150                     MISCHIEF, CRIMINAL 3 & 2, OF M
# 35151                                                NaN
#
#                                     Lat_Lon        BORO_NM
# 0                   (40.833567, -73.861118)          BRONX
# 1      (40.6488507469884, -73.951016510623)       BROOKLYN
# 2                    (40.619768, -74.08407)  STATEN ISLAND
# ...

# %%
# Dropping the missing values
selection.dropna()
# Out:
#                                                    Crime  \
# 0                                           ROBBERY,BANK
# 1                                                 RAPE 2
# 2      LARCENY,GRAND BY CREDIT CARD ACCT COMPROMISE-E...
# 3                              FRAUD,UNCLASSIFIED-FELONY
# 4                              FRAUD,UNCLASSIFIED-FELONY
# ...                                                  ...
# 35146                           ASSAULT 2,1,UNCLASSIFIED
# 35147                   CRIMINAL MISCHIEF,UNCLASSIFIED 4
# 35148                                          ASSAULT 3
# 35149                     CONTROLLED SUBSTANCE, POSSESSI
# 35150                     MISCHIEF, CRIMINAL 3 & 2, OF M
#
#                            Location(Lat_Lon)           Area
# 0                    (40.833567, -73.861118)          BRONX
# 1       (40.6488507469884, -73.951016510623)       BROOKLYN
# 2                     (40.619768, -74.08407)  STATEN ISLAND
# ...

# %%
#Naming colomn
selection.rename(columns = {'PD_DESC':'Crimes' , 'Lat_Lon':'Locations(Lat_Lon)' , 'BORO_NM' : 'Areas'}, inplace = True)
selection
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                                                    Crime  \
# 0                                           ROBBERY,BANK
# 1                                                 RAPE 2
# 2      LARCENY,GRAND BY CREDIT CARD ACCT COMPROMISE-E...
# 3                              FRAUD,UNCLASSIFIED-FELONY
# 4                              FRAUD,UNCLASSIFIED-FELONY
# ...                                                  ...
# 35147                   CRIMINAL MISCHIEF,UNCLASSIFIED 4
# 35148                                          ASSAULT 3
# 35149                     CONTROLLED SUBSTANCE, POSSESSI
# 35150                     MISCHIEF, CRIMINAL 3 & 2, OF M
# ...

# %%
#converting to excel
selection.to_excel("MapDataPreprocessing.xlsx")
